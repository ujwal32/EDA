# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# ## This is a Markdown Cell

# %%
df = pd.read_csv("machine-readable-business-employment-data-sep-2024-quarter.csv")

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 23732    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 23733    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 23734    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 23735    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 23736    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
df.describe()
# Out:
#              Period    Data_value     Magnitude  Series_title_4  \
# count  23737.000000  2.089800e+04  23737.000000             0.0
# mean    2017.347918  7.307587e+04      2.293382             NaN
# std        3.842658  2.114965e+05      2.915656             NaN
# min     2011.060000  1.187001e+00      0.000000             NaN
# 25%     2014.060000  1.895915e+03      0.000000             NaN
# 50%     2017.090000  1.415150e+04      0.000000             NaN
# 75%     2020.120000  6.065050e+04      6.000000             NaN
# max     2024.090000  2.321295e+06      6.000000             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
df.isnull()
# Out:
#        Series_reference  Period  Data_value  Suppressed  STATUS  UNITS  \
# 0                 False   False       False       False   False  False
# 1                 False   False       False       False   False  False
# 2                 False   False       False       False   False  False
# 3                 False   False       False       False   False  False
# 4                 False   False       False       False   False  False
# ...                 ...     ...         ...         ...     ...    ...
# 23732             False   False       False       False   False  False
# 23733             False   False       False       False   False  False
# 23734             False   False       False       False   False  False
# 23735             False   False       False       False   False  False
# 23736             False   False       False       False   False  False
#
#        Magnitude  Subject  Group  Series_title_1  Series_title_2  \
# ...

# %% [markdown]
# ## replacing nan value

# %%
df=df.fillna(0)

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0          0      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0          0      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0          0      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0          0      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0          0      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 23732    BDCQ.SEE3999A  2017.06         0.0          Y      C  Number
# 23733    BDCQ.SEE3999A  2017.09         0.0          Y      C  Number
# 23734    BDCQ.SEE3999A  2017.12         0.0          Y      C  Number
# 23735    BDCQ.SEE3999A  2018.03         0.0          Y      C  Number
# 23736    BDCQ.SEE3999A  2018.06         0.0          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
(df.groupby('Data_value').sum())
# Out:
#                                                Series_reference      Period  \
# Data_value
# 0.000000e+00  BDCQ.SEA2ASBDCQ.SEA2ASBDCQ.SEA2ASBDCQ.SEA2ASBD...  5722505.18
# 1.187001e+00                                      BDCQ.SEE2067A     2022.06
# 1.208340e+00                                      BDCQ.SEE2067A     2022.09
# 1.215571e+00                                      BDCQ.SEE2067A     2021.06
# 1.223237e+00                                      BDCQ.SEE2067A     2021.09
# ...                                                         ...         ...
# 2.303659e+06                                        BDCQ.SEA1ZA     2024.03
# 2.304238e+06                                        BDCQ.SEA1ZT     2023.12
# 2.304457e+06                                        BDCQ.SEA1ZT     2024.03
# 2.305803e+06                                        BDCQ.SEA1ZS     2024.03
# 2.321295e+06                                        BDCQ.SEA1ZA     2023.12
#
# ...

# %%
a = np.array([[1,2,3], [4,5,6]])
b = np.array([[np.random.randint(1,10,6)]])
c = np.array([np.random.randint(1,10,6)])

# %%
a,b,c  = (a.ravel(), b.ravel(), c.ravel())

# %%
a,b,c
# Out:
# (array([1, 2, 3, 4, 5, 6]),
#  array([5, 1, 9, 8, 8, 8]),
#  array([8, 2, 3, 6, 8, 7]))

# %%
dataframe_values = {'length':a, 'breadth':b, 'width':c}

# %%
dataframe_values
# Out:
# {'length': array([1, 2, 3, 4, 5, 6]),
#  'breadth': array([5, 1, 9, 8, 8, 8]),
#  'width': array([8, 2, 3, 6, 8, 7])}

# %%
new_df = pd.DataFrame(data=dataframe_values)

# %%
new_df
# Out:
#    length  breadth  width
# 0       1        5      8
# 1       2        1      2
# 2       3        9      3
# 3       4        8      6
# 4       5        8      8
# 5       6        8      7

# %%
new_df.plot(x='length', y='breadth', kind='pie', title="Length-breadth comparision")
plt.show()
